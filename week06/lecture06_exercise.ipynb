# %% [markdown]
# # Lecture 6 — Class Exercise
# ## Part-to-Whole: Hierarchical Visualization
#
# > **Push to:** `week06/lecture06_exercise.ipynb`
#
# **Rules:**
# 1. Use `px` first, then customise with `update_traces` / `update_layout`
# 2. Colour encodes a meaningful category — not decoration
# 3. Insight title names the specific finding
# 4. Consider: would a bar chart be clearer? If yes, use the bar chart
#
# ---

# %%
import pandas as pd
import plotly.express as px
import numpy as np

# Dataset: Global Energy Mix by Country and Source
df = pd.read_csv('../data/global_energy_mix.csv')

# Source type mapping — reuse from lecture
source_category = {
    'Coal': 'Fossil', 'Oil': 'Fossil', 'Natural Gas': 'Fossil',
    'Nuclear': 'Low-carbon', 'Hydro': 'Low-carbon',
    'Wind': 'Renewable', 'Solar': 'Renewable', 'Other Renewables': 'Renewable'
}
df['Source_Type'] = df['Source'].map(source_category)

print(f"Loaded: {len(df)} rows")
print(df.head(10))
# Out:
# Loaded: 103 rows
#          Country         Region            Source  Share_pct     TWh  \
# 0  United States  North America              Coal         10  1015.0
# 1  United States  North America               Oil         35  3220.0
# 2  United States  North America       Natural Gas         34  3083.0
# 3  United States  North America           Nuclear          9   798.0
# 4  United States  North America             Hydro          3   339.0
# 5  United States  North America              Wind          4   413.0
# 6  United States  North America             Solar          3   325.0
# 7  United States  North America  Other Renewables          2   229.0
# 8          China           Asia              Coal         60  7168.0
# 9          China           Asia               Oil         18  1620.0
#
#   Source_Type
# 0      Fossil
# 1      Fossil
# 2      Fossil
# 3  Low-carbon
# 4  Low-carbon
# 5   Renewable
# 6   Renewable
# 7   Renewable
# 8      Fossil
# 9      Fossil

# %% [markdown]
# ## Task 1 — Treemap: fossil fuel dependency by country
#
# **What to build:** A treemap showing **fossil fuel TWh only**, broken down by Region → Country → Source (Coal / Oil / Natural Gas).
#
# **Requirements:**
# - Filter to fossil sources only before plotting
# - Use `path=['Region', 'Country', 'Source']` for the hierarchy
# - Colour encodes the fossil source type (Coal / Oil / Natural Gas) with a CVD-safe palette
# - Show TWh values in labels — no percentages
# - Grey out parent nodes (Region and Country level)
# - Insight title naming which region or country is most fossil-dependent
#
# > 💡 `df.loc[df['Source_Type'] == 'Fossil']`

# %%
import plotly.io as pio
pio.renderers.default = "notebook_connected"

# %%
# ── Clean data ────────────────────────────────────────────────────────────────
fossil = (
    df[df['Source_Type'] == 'Fossil']
    .copy()
)

# Remove missing values
fossil = fossil.dropna(
    subset=['Region', 'Country', 'Source', 'TWh']
)

# Convert TWh to numeric
fossil['TWh'] = pd.to_numeric(fossil['TWh'], errors='coerce')

# Remove invalid rows
fossil = fossil[fossil['TWh'] > 0]

# IMPORTANT: aggregate duplicates
fossil = (
    fossil.groupby(
        ['Region', 'Country', 'Source'],
        as_index=False
    )['TWh']
    .sum()
)

print(fossil.head())
print(fossil.shape)

# ── Colors ────────────────────────────────────────────────────────────────────
fossil_color_map = {
    'Coal': '#4E3B2D',
    'Oil': '#E07B39',
    'Natural Gas': '#6BAED6',
}

# ── Treemap ───────────────────────────────────────────────────────────────────
fig = px.treemap(
    fossil,
    path=[px.Constant("World"), 'Region', 'Country', 'Source'],
    values='TWh',
    color='Source',
    color_discrete_map=fossil_color_map,
    height=700,
    width=1300
)

# ── Labels ────────────────────────────────────────────────────────────────────
fig.update_traces(
    texttemplate='%{label}<br>%{value:,.0f} TWh',
    hovertemplate='<b>%{label}</b><br>%{value:,.0f} TWh<extra></extra>',
)

# ── Grey parents ──────────────────────────────────────────────────────────────
new_colors = []

for label in fig.data[0].labels:
    if label in fossil_color_map:
        new_colors.append(fossil_color_map[label])
    else:
        new_colors.append('#DDDDDD')

fig.data[0].marker.colors = new_colors

# ── Layout ────────────────────────────────────────────────────────────────────
fig.update_layout(
    title='Asia dominates global fossil fuel consumption',
    margin=dict(t=60, l=10, r=10, b=10),
    paper_bgcolor='white'
)

fig.show()
# Out:
#    Region       Country       Source     TWh
# 0  Africa  South Africa         Coal  6727.0
# 1  Africa  South Africa  Natural Gas   472.0
# 2  Africa  South Africa          Oil  1421.0
# 3    Asia         China         Coal  7168.0
# 4    Asia         China  Natural Gas   872.0
# (43, 4)
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="134b2508-140d-454a-b4b3-729915bb418e" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("134b2508-140d-454a-b4b3-729915bb418e")) {                    Plotly.newPlot(                        "134b2508-140d-454a-b4b3-729915bb418e",                        [{"branchvalues":"total","customdata":[["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["Coal"],["Coal"],["Coal"],["Coal"],["Coal"],["Coal"],["Coal"],["Coal"],["Coal"],["Coal"],["Coal"],["Coal"],["Coal"],["Natural Gas"],["Natural Gas"],["Natural Gas"],["Natural Gas"],["Natural Gas"],["Natural Gas"],["Natural Gas"],["Natural Gas"],["Natural Gas"],["Natural Gas"],["Natural Gas"],["Natural Gas"],["Natural Gas"],["Natural Gas"],["Natural Gas"],["Oil"],["Oil"],["Oil"],["Oil"],["Oil"],["Oil"],["Oil"],["Oil"],["Oil"],["Oil"],["Oil"],["Oil"],["Oil"],["Oil"],["Oil"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"\u003cb\u003e%{label}\u003c\u002fb\u003e\u003cbr\u003e%{value:,.0f} TWh\u003cextra\u003e\u003c\u002fextra\u003e","ids":["World","World\u002fAfrica\u002fSouth Africa","World\u002fAsia\u002fChina","World\u002fAsia\u002fIndia","World\u002fAsia\u002fJapan","World\u002fAsia\u002fSouth Korea","World\u002fEurope\u002fFrance","World\u002fEurope\u002fGermany","World\u002fEurope\u002fNorway","World\u002fOceania","World\u002fLatin America\u002fBrazil","World\u002fEurope\u002fUnited Kingdom","World\u002fMiddle East\u002fSaudi Arabia","World\u002fNorth America\u002fCanada","World\u002fNorth America\u002fUnited States","World\u002fOceania\u002fAustralia","World\u002fAfrica","World\u002fAsia","World\u002fEurope","World\u002fLatin America","World\u002fMiddle East","World\u002fNorth America","World\u002fLatin America\u002fMexico","World\u002fOceania\u002fAustralia\u002fCoal","World\u002fNorth America\u002fUnited States\u002fCoal","World\u002fNorth America\u002fCanada\u002fCoal","World\u002fLatin America\u002fMexico\u002fCoal","World\u002fAfrica\u002fSouth Africa\u002fCoal","World\u002fEurope\u002fGermany\u002fCoal","World\u002fLatin America\u002fBrazil\u002fCoal","World\u002fAsia\u002fChina\u002fCoal","World\u002fAsia\u002fIndia\u002fCoal","World\u002fAsia\u002fJapan\u002fCoal","World\u002fEurope\u002fUnited Kingdom\u002fCoal","World\u002fAsia\u002fSouth Korea\u002fCoal","World\u002fEurope\u002fFrance\u002fCoal","World\u002fAfrica\u002fSouth Africa\u002fNatural Gas","World\u002fAsia\u002fChina\u002fNatural Gas","World\u002fAsia\u002fIndia\u002fNatural Gas","World\u002fAsia\u002fJapan\u002fNatural Gas","World\u002fAsia\u002fSouth Korea\u002fNatural Gas","World\u002fEurope\u002fFrance\u002fNatural Gas","World\u002fLatin America\u002fBrazil\u002fNatural Gas","World\u002fEurope\u002fGermany\u002fNatural Gas","World\u002fMiddle East\u002fSaudi Arabia\u002fNatural Gas","World\u002fEurope\u002fNorway\u002fNatural Gas","World\u002fLatin America\u002fMexico\u002fNatural Gas","World\u002fEurope\u002fUnited Kingdom\u002fNatural Gas","World\u002fNorth America\u002fUnited States\u002fNatural Gas","World\u002fNorth America\u002fCanada\u002fNatural Gas","World\u002fOceania\u002fAustralia\u002fNatural Gas","World\u002fAsia\u002fSouth Korea\u002fOil","World\u002fNorth America\u002fUnited States\u002fOil","World\u002fAsia\u002fJapan\u002fOil","World\u002fNorth America\u002fCanada\u002fOil","World\u002fEurope\u002fGermany\u002fOil","World\u002fAsia\u002fIndia\u002fOil","World\u002fEurope\u002fFrance\u002fOil","World\u002fMiddle East\u002fSaudi Arabia\u002fOil","World\u002fAsia\u002fChina\u002fOil","World\u002fEurope\u002fUnite ...

# %% [markdown]
# ## Task 2 — Sunburst: tipping behaviour by day and meal time
#
# **What to build:** A sunburst chart using the built-in `tips` dataset showing how **total bill amount** is distributed across day → time → smoker status.
#
# **Requirements:**
# - Load tips with `px.data.tips()`
# - Aggregate **total bill** (sum of `total_bill`) per group — not count
# - Hierarchy: `path=['day', 'time', 'smoker']`
# - Colour encodes smoker status with a CVD-safe blue/orange palette
# - Grey out parent nodes (day and time level)
# - Use `percent parent` for text labels
# - Insight title describing where the most spending happens
#
# > 💡 `tips.groupby(['day', 'time', 'smoker'])['total_bill'].sum().reset_index()`

# %%
# Task 2 — Sunburst: tipping behaviour by day and meal time

# ── Data prep ─────────────────────────────────────────────────────────────────
tips = px.data.tips()

# Aggregate total_bill (sum) per group — not count
df_sun = (
    tips.groupby(['day', 'time', 'smoker'])['total_bill']
    .sum()
    .reset_index()
)

# CVD-safe blue/orange palette for smoker status
smoker_color_map = {
    'No':  '#2E75B6',   # blue  — non-smoker
    'Yes': '#E07B39',   # orange — smoker
}

# ── Step 1: Plotly Express base chart ─────────────────────────────────────────
fig = px.sunburst(
    df_sun,
    path=['day', 'time', 'smoker'],
    values='total_bill',
    color='smoker',
    color_discrete_map=smoker_color_map,
    labels={'total_bill': 'Total Bill ($)', 'smoker': 'Smoker'},
    height=600, width=650
)

# ── Step 2: percent parent labels ─────────────────────────────────────────────
fig.update_traces(
    textinfo='label+percent parent',
    hovertemplate='<b>%{label}</b><br>Total bill: $%{value:,.2f}<br>%{percentParent:.0%} of %{parent}<extra></extra>',
    insidetextorientation='radial',
)

# ── Step 3: Grey out parent nodes (day and time) ──────────────────────────────
fig.data[0].marker.colors = [
    c if c in smoker_color_map.values() else '#DDDDDD'
    for c in fig.data[0].marker.colors
]

# ── Step 4: Layout ────────────────────────────────────────────────────────────
fig.update_layout(
    title='Saturday dinner drives the most spending — non-smokers account for the majority of bills every day',
    font=dict(family='Arial', size=12),
    margin=dict(l=10, r=10, t=60, b=10),
    paper_bgcolor='white',
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="32af5e94-868d-4ae2-b199-7f07d53c6df1" class="plotly-graph-div" style="height:600px; width:650px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("32af5e94-868d-4ae2-b199-7f07d53c6df1")) {                    Plotly.newPlot(                        "32af5e94-868d-4ae2-b199-7f07d53c6df1",                        [{"branchvalues":"total","customdata":[["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["No"],["No"],["No"],["No"],["No"],["No"],["No"],["Yes"],["Yes"],["Yes"],["Yes"],["Yes"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"\u003cb\u003e%{label}\u003c\u002fb\u003e\u003cbr\u003eTotal bill: $%{value:,.2f}\u003cbr\u003e%{percentParent:.0%} of %{parent}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Thur","Sat","Fri","Thur\u002fLunch","Sun\u002fDinner","Sat\u002fDinner","Fri\u002fLunch","Fri\u002fDinner","Sun","Thur\u002fDinner","Fri\u002fDinner\u002fNo","Thur\u002fDinner\u002fNo","Sun\u002fDinner\u002fNo","Sat\u002fDinner\u002fNo","Fri\u002fLunch\u002fNo","Thur\u002fLunch\u002fNo","Sun\u002fDinner\u002fYes","Sat\u002fDinner\u002fYes","Fri\u002fLunch\u002fYes","Fri\u002fDinner\u002fYes","Thur\u002fLunch\u002fYes"],"labels":["Thur","Sat","Fri","Lunch","Dinner","Dinner","Lunch","Dinner","Sun","Dinner","No","No","No","No","No","No","Yes","Yes","Yes","Yes","Yes"],"marker":{"colors":["#DDDDDD","#DDDDDD","#DDDDDD","#DDDDDD","#DDDDDD","#DDDDDD","#DDDDDD","#DDDDDD","#DDDDDD","#2E75B6","#2E75B6","#2E75B6","#2E75B6","#2E75B6","#2E75B6","#2E75B6","#E07B39","#E07B39","#E07B39","#E07B39","#E07B39"]},"name":"","parents":["","","","Thur","Sun","Sat","Fri","Fri","","Thur","Fri\u002fDinner","Thur\u002fDinner","Sun\u002fDinner","Sat\u002fDinner","Fri\u002fLunch","Thur\u002fLunch","Sun\u002fDinner","Sat\u002fDinner","Fri\u002fLunch","Fri\u002fDinner","Thur\u002fLunch"],"values":{"dtype":"f8","bdata":"uB6F61EhkUCamZmZmcmbQK5H4XoUXnRAMzMzMzPWkEBwPQrXo2yZQJqZmZmZyZtAexSuR+F6VkAehetRuH5tQHA9CtejbJlASOF6FK7HMkCamZmZmdlMQEjhehSuxzJA61G4HoVDkkAK16NwPaaLQPYoXI\u002fC9S9AFK5H4Xp6h0AUrkfheqR8QClcj8L17ItAXI\u002fC9Sh8UkC4HoXrUUhmQKRwPQrXY3RA"},"type":"sunburst","insidetextorientation":"radial","textinfo":"label+percent parent"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0. ...

# %% [markdown]
# ## Task 3 — Treemap vs bar: low-carbon energy by country
#
# **What to build:** Build **both** a treemap and a horizontal bar chart showing total low-carbon TWh (Nuclear + Hydro) per country. Then answer the question in a markdown cell below.
#
# **Requirements:**
# - Filter to `Source_Type == 'Low-carbon'` and aggregate TWh by country
# - Treemap: single-level `path=['All', 'Country']` with a dummy root node labelled `'Low-carbon'`
# - Bar chart: sorted by TWh, horizontal orientation, CVD-safe colour
# - Both charts show TWh values, not percentages
# - Insight title on the bar chart naming the leading country

# %%
# Task 3 — Treemap vs bar: low-carbon energy by country

# ── Data prep ─────────────────────────────────────────────────────────────────
low_carbon = (
    df.loc[df['Source_Type'] == 'Low-carbon']
    .groupby('Country')['TWh']
    .sum()
    .reset_index()
    .sort_values('TWh')            # ascending — bar chart reads bottom-to-top
)

low_carbon['All'] = 'Low-carbon'  # dummy root node with a meaningful label

# ── Treemap ───────────────────────────────────────────────────────────────────
fig_tree = px.treemap(
    low_carbon,
    path=['All', 'Country'],
    values='TWh',
    color='TWh',
    color_continuous_scale='magenta',
    title='Low-carbon energy by country — China and USA lead by total volume',
    labels={'TWh': 'Low-carbon Energy (TWh)'},
    height=500, width=900
)
fig_tree.update_traces(
    texttemplate='%{label}<br>%{value:,.0f} TWh',
    hovertemplate='<b>%{label}</b><br>%{value:,.0f} TWh<extra></extra>',
    root_color='white',
)
fig_tree.update_layout(
    font=dict(family='Arial', size=12),
    margin=dict(l=10, r=10, t=60, b=10),
    paper_bgcolor='white',
)
fig_tree.show()

# ── Bar chart ─────────────────────────────────────────────────────────────────
fig_bar = px.bar(
    low_carbon,
    x='TWh',
    y='Country',
    orientation='h',
    color='TWh',
    color_continuous_scale='magenta',
    title='China leads on low-carbon energy (Nuclear + Hydro) — Norway punches above its weight on a per-capita basis',
    labels={'TWh': 'Low-carbon Energy (TWh)', 'Country': ''},
    height=500, width=800
)
fig_bar.update_traces(
    texttemplate='%{x:,.0f} TWh',
    textposition='outside',
)
fig_bar.update_layout(
    plot_bgcolor='white',
    paper_bgcolor='white',
    font=dict(family='Arial', size=10),
    coloraxis_showscale=False,
    margin=dict(l=10, r=80, t=60, b=10),
)
fig_bar.update_xaxes(gridcolor='#EEEEEE')
fig_bar.update_yaxes(gridcolor='#EEEEEE')
fig_bar.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="c205f647-52dd-476a-9da3-48e61113bb80" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c205f647-52dd-476a-9da3-48e61113bb80")) {                    Plotly.newPlot(                        "c205f647-52dd-476a-9da3-48e61113bb80",                        [{"branchvalues":"total","customdata":{"dtype":"f8","bdata":"AAAAAAAAfEAAAAAAALCGQAAAAAAAkItAAAAAAABQjEAAAAAAAAiNQAAAAAAACI9AAAAAAACgj0AAAAAAAMSRQAAAAAAA4JRAAAAAAABoo0AAAAAAAG+zQAAAAAAAUbdAAAAAAAAeuEAAAAAAAKm9QJcyuaD2vLJA","shape":"15, 1"},"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"\u003cb\u003e%{label}\u003c\u002fb\u003e\u003cbr\u003e%{value:,.0f} TWh\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Low-carbon\u002fAustralia","Low-carbon\u002fSouth Africa","Low-carbon\u002fChina","Low-carbon\u002fMexico","Low-carbon\u002fGermany","Low-carbon\u002fUnited Kingdom","Low-carbon\u002fJapan","Low-carbon\u002fUnited States","Low-carbon\u002fIndia","Low-carbon\u002fSouth Korea","Low-carbon\u002fBrazil","Low-carbon\u002fCanada","Low-carbon\u002fNorway","Low-carbon\u002fFrance","Low-carbon"],"labels":["Australia","South Africa","China","Mexico","Germany","United Kingdom","Japan","United States","India","South Korea","Brazil","Canada","Norway","France","Low-carbon"],"marker":{"coloraxis":"coloraxis","colors":{"dtype":"f8","bdata":"AAAAAAAAfEAAAAAAALCGQAAAAAAAkItAAAAAAABQjEAAAAAAAAiNQAAAAAAACI9AAAAAAACgj0AAAAAAAMSRQAAAAAAA4JRAAAAAAABoo0AAAAAAAG+zQAAAAAAAUbdAAAAAAAAeuEAAAAAAAKm9QJcyuaD2vLJA"}},"name":"","parents":["Low-carbon","Low-carbon","Low-carbon","Low-carbon","Low-carbon","Low-carbon","Low-carbon","Low-carbon","Low-carbon","Low-carbon","Low-carbon","Low-carbon","Low-carbon","Low-carbon",""],"values":{"dtype":"f8","bdata":"AAAAAAAAfEAAAAAAALCGQAAAAAAAkItAAAAAAABQjEAAAAAAAAiNQAAAAAAACI9AAAAAAACgj0AAAAAAAMSRQAAAAAAA4JRAAAAAAABoo0AAAAAAAG+zQAAAAAAAUbdAAAAAAAAeuEAAAAAAAKm9QAAAAACAXeFA"},"type":"treemap","root":{"color":"white"},"texttemplate":"%{label}\u003cbr\u003e%{value:,.0f} TWh"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fd ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="2ea70316-06e6-41f0-a05f-41b86e3841c7" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2ea70316-06e6-41f0-a05f-41b86e3841c7")) {                    Plotly.newPlot(                        "2ea70316-06e6-41f0-a05f-41b86e3841c7",                        [{"hovertemplate":"Low-carbon Energy (TWh)=%{marker.color}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"f8","bdata":"AAAAAAAAfEAAAAAAALCGQAAAAAAAkItAAAAAAABQjEAAAAAAAAiNQAAAAAAACI9AAAAAAACgj0AAAAAAAMSRQAAAAAAA4JRAAAAAAABoo0AAAAAAAG+zQAAAAAAAUbdAAAAAAAAeuEAAAAAAAKm9QA=="},"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","orientation":"h","showlegend":false,"textposition":"outside","x":{"dtype":"f8","bdata":"AAAAAAAAfEAAAAAAALCGQAAAAAAAkItAAAAAAABQjEAAAAAAAAiNQAAAAAAACI9AAAAAAACgj0AAAAAAAMSRQAAAAAAA4JRAAAAAAABoo0AAAAAAAG+zQAAAAAAAUbdAAAAAAAAeuEAAAAAAAKm9QA=="},"xaxis":"x","y":["Australia","South Africa","China","Mexico","Germany","United Kingdom","Japan","United States","India","South Korea","Brazil","Canada","Norway","France"],"yaxis":"y","type":"bar","texttemplate":"%{x:,.0f} TWh"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5} ...
